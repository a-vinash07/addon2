# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\user\Downloads\auto-mpg.csv')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
plt.hist(data['mpg'],color = 'orange',rwidth = 0.9)
plt.title('Histogram of mpg')
plt.xlabel('mpg')
plt.ylabel('distribution of mpg')
plt.show()

# %%
plt.hist(data['acceleration'],color = 'red',rwidth = 0.9)
plt.title('Histogram of acceleration')
plt.xlabel('acceleration')
plt.ylabel('distribution of acceleration')
plt.show()

# %%
plt.scatter(data['weight'],data['mpg'])
plt.show()
